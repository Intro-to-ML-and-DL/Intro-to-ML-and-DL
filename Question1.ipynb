# %%
from sklearn.datasets import make_regression
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
X_test, y_test = make_regression(n_samples=1000, n_features=5, noise=0)

# %%
rows, cols = (1000, 1)
X1_test = [[0 for i in range(cols)] for j in range(rows)]
for i in range(1000):
  X1_test[i][0]=X_test[i][0]
l1 = LinearRegression()
l1.fit(X1_test, y_test)
Y1_pred = l1.predict(X1_test)
plt.scatter(X1_test,y_test)
plt.plot(X1_test, Y1_pred, color='red')
plt.show()

# %%
rows, cols = (1000, 1)
X2_test = [[0 for i in range(cols)] for j in range(rows)]
for i in range(1000):
  X2_test[i][0]=X_test[i][1]
l2 = LinearRegression()
l2.fit(X2_test, y_test)
Y2_pred = l2.predict(X2_test)
plt.scatter(X2_test,y_test)
plt.plot(X2_test, Y2_pred, color='red')
plt.show()

# %%
rows, cols = (1000, 1)
X3_test = [[0 for i in range(cols)] for j in range(rows)]
for i in range(1000):
  X3_test[i][0]=X_test[i][2]
l3 = LinearRegression()
l3.fit(X3_test, y_test)
Y3_pred = l3.predict(X3_test)
plt.scatter(X3_test,y_test)
plt.plot(X3_test, Y3_pred, color='red')
plt.show()

# %%
rows, cols = (1000, 1)
X4_test = [[0 for i in range(cols)] for j in range(rows)]
for i in range(1000):
  X4_test[i][0]=X_test[i][3]
l4 = LinearRegression()
l4.fit(X4_test, y_test)
Y4_pred = l4.predict(X4_test)
plt.scatter(X4_test,y_test)
plt.plot(X4_test, Y4_pred, color='red')
plt.show()

# %%
rows, cols = (1000, 1)
X5_test = [[0 for i in range(cols)] for j in range(rows)]
for i in range(1000):
  X5_test[i][0]=X_test[i][4]
l5 = LinearRegression()
l5.fit(X5_test, y_test)
Y5_pred = l5.predict(X5_test)
plt.scatter(X5_test,y_test)
plt.plot(X5_test, Y5_pred, color='red')
plt.show()
