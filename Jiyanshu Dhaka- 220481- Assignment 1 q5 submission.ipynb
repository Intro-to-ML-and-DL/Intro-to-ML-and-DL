# %%
import numpy as np
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
from collections import Counter
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

, y = make_classification(n_samples=1000, n_features=2, n_classes=2, n_clusters_per_class=1, n_informative=2, n_redundant=0, weights=(0.95, 0.05))
fig, axs = plt.subplots(1, 3, figsize=(17, 5))

print('imbalanced data:')
print(Counter(y))

axs[0].scatter(x[:, 0], x[:, 1], c=y)
axs[0].set_title('Imbalanced Dataset')

oversample = SMOTE(sampling_strategy=0.2632)
x1, y1 = oversample.fit_resample(x, y)

print('after oversampling:')
print(Counter(y1))

axs[1].scatter(x1[:, 0], x1[:, 1], c=y1)
axs[1].set_title('OverSampled Dataset')

undersample = RandomUnderSampler(sampling_strategy=0.3333)
x2, y2 = undersample.fit_resample(x1, y1)

print('after undersampling:')
print(Counter(y2))

axs[2].scatter(x2[:, 0], x2[:, 1], c=y2)
axs[2].set_title('UnderSampled Dataset')

plt.show()
# Out:
# imbalanced data:
# Counter({0: 946, 1: 54})
# after oversampling:
# Counter({0: 946, 1: 248})
# after undersampling:
# Counter({0: 744, 1: 248})
